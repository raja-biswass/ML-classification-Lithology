# %%
import numpy as np 
import pandas as pd
import glob

# %%
from pycaret.classification import *

# %%
my_data = pd.read_csv("Classifi_all_data_afterFI.csv")
my_data.head()
# Out:
#           VV   Entropy  Anisotropy   GLCM PC1  DEM    PC1    PC2       PC3  \
# 0 -19.127264  0.802243    0.511247 -11.121046   46  1.045  0.114  0.089072
# 1 -17.905613  0.783197    0.534009 -11.905989   54  1.049  0.117  0.090146
# 2 -15.280186  0.771204    0.547740  -7.164552   54  1.027  0.126  0.087076
# 3 -14.594241  0.814251    0.496232  -5.439240   59  1.005  0.115  0.085156
# 4 -14.800154  0.846771    0.452534  -4.033033   53  1.020  0.122  0.082730
#
#         PC4       PC6  ClassID Class_name
# 0  0.028547  0.008142        1        ASK
# 1  0.029851  0.008729        1        ASK
# 2  0.028418  0.005288        1        ASK
# 3  0.031047  0.008023        1        ASK
# 4  0.032016  0.004915        1        ASK

# %%
my_data.drop(['ClassID'], axis = 1, inplace = True)

# %%
my_data.head()
# Out:
#           VV   Entropy  Anisotropy   GLCM PC1  DEM    PC1    PC2       PC3  \
# 0 -19.127264  0.802243    0.511247 -11.121046   46  1.045  0.114  0.089072
# 1 -17.905613  0.783197    0.534009 -11.905989   54  1.049  0.117  0.090146
# 2 -15.280186  0.771204    0.547740  -7.164552   54  1.027  0.126  0.087076
# 3 -14.594241  0.814251    0.496232  -5.439240   59  1.005  0.115  0.085156
# 4 -14.800154  0.846771    0.452534  -4.033033   53  1.020  0.122  0.082730
#
#         PC4       PC6 Class_name
# 0  0.028547  0.008142        ASK
# 1  0.029851  0.008729        ASK
# 2  0.028418  0.005288        ASK
# 3  0.031047  0.008023        ASK
# 4  0.032016  0.004915        ASK

# %%
cls_all_fi = setup(my_data, target = 'Class_name',train_size = 0.7,session_id=123,log_experiment=True, experiment_name='cls_all_fi')
# Out:
# <style type="text/css">
# #T_22e45_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22e45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22e45_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22e45_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22e45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22e45_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_22e45_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_22e45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22e45_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22e45_row1_col1" class="data row1 col1" >Class_name</td>
#     </tr>
#     <tr>
#       <th id="T_22e45_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_1f8a0 th {
#   text-align: left;
# }
# ...
