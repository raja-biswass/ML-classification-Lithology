# %%
import numpy as np 
import pandas as pd
import glob

# %%
from pycaret.classification import *

# %%
my_data = pd.read_csv("Classifi_glcm_data.csv")
my_data.head()
# Out:
#     GLCM PC1  GLCM PC2  GLCM PC3  GLCM PC4  GLCM PC5  GLCM PC6  ClassID  \
# 0 -11.121046  2.120520 -1.187986  0.305749 -0.217070  0.766538        1
# 1 -11.905989 -0.035668  0.034768  0.406617 -0.557473 -0.152389        1
# 2  -7.164552 -7.279618  0.445399  1.520445 -0.423039 -1.244990        1
# 3  -5.439240  0.077479 -1.435103 -0.307729 -0.324791 -0.860380        1
# 4  -4.033033  0.462254  2.218574 -0.027918 -0.247315 -0.528220        1
#
#   Class_name
# 0        ASK
# 1        ASK
# 2        ASK
# 3        ASK
# 4        ASK

# %%
my_data.drop(['ClassID'], axis = 1, inplace = True)

# %%
my_data.head()
# Out:
#     GLCM PC1  GLCM PC2  GLCM PC3  GLCM PC4  GLCM PC5  GLCM PC6 Class_name
# 0 -11.121046  2.120520 -1.187986  0.305749 -0.217070  0.766538        ASK
# 1 -11.905989 -0.035668  0.034768  0.406617 -0.557473 -0.152389        ASK
# 2  -7.164552 -7.279618  0.445399  1.520445 -0.423039 -1.244990        ASK
# 3  -5.439240  0.077479 -1.435103 -0.307729 -0.324791 -0.860380        ASK
# 4  -4.033033  0.462254  2.218574 -0.027918 -0.247315 -0.528220        ASK

# %%
cls_glcm = setup(my_data, target = 'Class_name',train_size = 0.7,session_id=123,log_experiment=True, experiment_name='cls_glcm')
# Out:
# <style type="text/css">
# #T_b6769_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b6769">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6769_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b6769_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6769_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6769_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b6769_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b6769_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6769_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b6769_row1_col1" class="data row1 col1" >Class_name</td>
#     </tr>
#     <tr>
#       <th id="T_b6769_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ae14f th {
#   text-align: left;
# }
# ...
