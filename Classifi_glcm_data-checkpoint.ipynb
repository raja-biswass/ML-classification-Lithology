# %%
import numpy as np 
import pandas as pd
import glob

# %%
from pycaret.classification import *

# %%
my_data = pd.read_csv("Classifi_decom_data.csv")
my_data.head()
# Out:
#     Entropy  Anisotropy      Alpha  ClassID Class_name
# 0  0.802243    0.511247  24.109398        1        ASK
# 1  0.783197    0.534009  24.449989        1        ASK
# 2  0.771204    0.547740  23.534164        1        ASK
# 3  0.814251    0.496232  24.446283        1        ASK
# 4  0.846771    0.452534  28.770714        1        ASK

# %%
my_data.drop(['ClassID'], axis = 1, inplace = True)

# %%
my_data.head()
# Out:
#     Entropy  Anisotropy      Alpha Class_name
# 0  0.802243    0.511247  24.109398        ASK
# 1  0.783197    0.534009  24.449989        ASK
# 2  0.771204    0.547740  23.534164        ASK
# 3  0.814251    0.496232  24.446283        ASK
# 4  0.846771    0.452534  28.770714        ASK

# %%
cls_decom = setup(my_data, target = 'Class_name',train_size = 0.7,session_id=123,log_experiment=True, experiment_name='cls_decom')
# Out:
# <style type="text/css">
# #T_a5333_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5333">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5333_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5333_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5333_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5333_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5333_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a5333_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5333_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5333_row1_col1" class="data row1 col1" >Class_name</td>
#     </tr>
#     <tr>
#       <th id="T_a5333_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_1c209 th {
#   text-align: left;
# }
# ...
