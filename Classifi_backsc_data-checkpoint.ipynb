# %%
import numpy as np 
import pandas as pd
import glob

# %%
from pycaret.classification import *

# %%
my_data = pd.read_csv("Classifi_all_data_beforeFI.csv")
my_data.head()
# Out:
#           VV         VH     VV-VH   Entropy  Anisotropy      Alpha   GLCM PC1  \
# 0 -19.127264 -26.148289  7.021025  0.802243    0.511247  24.109398 -11.121046
# 1 -17.905613 -27.497355  9.591742  0.783197    0.534009  24.449989 -11.905989
# 2 -15.280186 -22.360802  7.080616  0.771204    0.547740  23.534164  -7.164552
# 3 -14.594241 -20.822491  6.228250  0.814251    0.496232  24.446283  -5.439240
# 4 -14.800154 -19.735399  4.935246  0.846771    0.452534  28.770714  -4.033033
#
#    GLCM PC2  GLCM PC3  GLCM PC4  ...  GLCM PC6  DEM    PC1    PC2       PC3  \
# 0  2.120520 -1.187986  0.305749  ...  0.766538   46  1.045  0.114  0.089072
# 1 -0.035668  0.034768  0.406617  ... -0.152389   54  1.049  0.117  0.090146
# 2 -7.279618  0.445399  1.520445  ... -1.244990   54  1.027  0.126  0.087076
# 3  0.077479 -1.435103 -0.307729  ... -0.860380   59  1.005  0.115  0.085156
# 4  0.462254  2.218574 -0.027918  ... -0.528220   53  1.020  0.122  0.082730
#
# ...

# %%
my_data.drop(['ClassID'], axis = 1, inplace = True)

# %%
my_data.head()
# Out:
#           VV         VH     VV-VH   Entropy  Anisotropy      Alpha   GLCM PC1  \
# 0 -19.127264 -26.148289  7.021025  0.802243    0.511247  24.109398 -11.121046
# 1 -17.905613 -27.497355  9.591742  0.783197    0.534009  24.449989 -11.905989
# 2 -15.280186 -22.360802  7.080616  0.771204    0.547740  23.534164  -7.164552
# 3 -14.594241 -20.822491  6.228250  0.814251    0.496232  24.446283  -5.439240
# 4 -14.800154 -19.735399  4.935246  0.846771    0.452534  28.770714  -4.033033
#
#    GLCM PC2  GLCM PC3  GLCM PC4  GLCM PC5  GLCM PC6  DEM    PC1    PC2  \
# 0  2.120520 -1.187986  0.305749 -0.217070  0.766538   46  1.045  0.114
# 1 -0.035668  0.034768  0.406617 -0.557473 -0.152389   54  1.049  0.117
# 2 -7.279618  0.445399  1.520445 -0.423039 -1.244990   54  1.027  0.126
# 3  0.077479 -1.435103 -0.307729 -0.324791 -0.860380   59  1.005  0.115
# 4  0.462254  2.218574 -0.027918 -0.247315 -0.528220   53  1.020  0.122
#
#         PC3       PC4       PC5       PC6 Class_name
# ...

# %%
cls_all = setup(my_data, target = 'Class_name',train_size = 0.7,session_id=123,log_experiment=True, experiment_name='cls_all')
# Out:
# <style type="text/css">
# #T_66b04_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_66b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66b04_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_66b04_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66b04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66b04_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_66b04_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_66b04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66b04_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_66b04_row1_col1" class="data row1 col1" >Class_name</td>
#     </tr>
#     <tr>
#       <th id="T_66b04_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4c386 th {
#   text-align: left;
# }
# ...
