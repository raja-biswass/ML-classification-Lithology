# %%
import numpy as np 
import pandas as pd
import glob

# %%
from pycaret.classification import *

# %%
my_data = pd.read_csv("Classifi_backsc_data.csv")
my_data.head()
# Out:
#           VV         VH     VV-VH  ClassID Class_name
# 0 -19.127264 -26.148289  7.021025        1        ASK
# 1 -17.905613 -27.497355  9.591742        1        ASK
# 2 -15.280186 -22.360802  7.080616        1        ASK
# 3 -14.594241 -20.822491  6.228250        1        ASK
# 4 -14.800154 -19.735399  4.935246        1        ASK

# %%
my_data.drop(['ClassID'], axis = 1, inplace = True)

# %%
my_data.head()
# Out:
#           VV         VH     VV-VH Class_name
# 0 -19.127264 -26.148289  7.021025        ASK
# 1 -17.905613 -27.497355  9.591742        ASK
# 2 -15.280186 -22.360802  7.080616        ASK
# 3 -14.594241 -20.822491  6.228250        ASK
# 4 -14.800154 -19.735399  4.935246        ASK

# %%
cls_bcks = setup(my_data, target = 'Class_name',train_size = 0.7,session_id=123,log_experiment=True, experiment_name='cls_bcks')
# Out:
# <style type="text/css">
# #T_449e6_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_449e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_449e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_449e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_449e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_449e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_449e6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_449e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_449e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_449e6_row1_col1" class="data row1 col1" >Class_name</td>
#     </tr>
#     <tr>
#       <th id="T_449e6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_c5d4c th {
#   text-align: left;
# }
# ...
